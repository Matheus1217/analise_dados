# %% [markdown]
# # Análise da Tabela 3
#
# Ajuste dos dados por região e resumo estatístico dos grupos principais.

# %%
import pandas as pd

mapeamento_planilhas = {
    'Graduação': 'tabela3_01_curso_superior_por_regiao.xlsx',
    'Exatas/Tecnologia': 'tabela3_02_ciencia_tecnologia_engenharias_matematica_por_regiao.xlsx',
    'Saúde/Educação': 'tabela3_03_educacao_servicos_saude_bem_estar_por_regiao.xlsx',
}

dados_importados = {rotulo: pd.read_excel(caminho, skiprows=2) for rotulo, caminho in mapeamento_planilhas.items()}
list(dados_importados.keys())

# %% [markdown]
# ## Região: população com ensino superior completo

# %%
df_superior = pd.DataFrame([
    {'Região': 'Norte', 'Total': 1525166, 'Homens': 590558, 'Mulheres': 934609},
    {'Região': 'Nordeste', 'Total': 4748933, 'Homens': 1744994, 'Mulheres': 3003939},
    {'Região': 'Sudeste', 'Total': 12828829, 'Homens': 5391638, 'Mulheres': 7437191},
    {'Região': 'Sul', 'Total': 4338861, 'Homens': 1768855, 'Mulheres': 2570005},
    {'Região': 'Centro-Oeste', 'Total': 2412502, 'Homens': 982489, 'Mulheres': 1430013}
])
df_superior

# %%
df_superior.describe()
# Out:
#                 Total          Homens        Mulheres
# count             5.0             5.0             5.0
# mean        5170858.2       2095706.8       3075151.4
# std    4483702.642127  1910348.189648  2577597.509536
# min         1525166.0        590558.0        934609.0
# 25%         2412502.0        982489.0       1430013.0
# 50%         4338861.0       1744994.0       2570005.0
# 75%         4748933.0       1768855.0       3003939.0
# max        12828829.0       5391638.0       7437191.0

# %% [markdown]
# ## Região: profissionais nas áreas de STEM

# %%
df_ctem = pd.DataFrame([
    {'Região': 'Norte', 'Total': 209657, 'Homens': 133055, 'Mulheres': 76601},
    {'Região': 'Nordeste', 'Total': 621388, 'Homens': 389993, 'Mulheres': 231395},
    {'Região': 'Sudeste', 'Total': 2328122, 'Homens': 1588874, 'Mulheres': 739247},
    {'Região': 'Sul', 'Total': 662916, 'Homens': 427372, 'Mulheres': 235543},
    {'Região': 'Centro-Oeste', 'Total': 326959, 'Homens': 211124, 'Mulheres': 115834}
])
df_ctem

# %%
df_ctem.describe()
# Out:
#               Total         Homens       Mulheres
# count           5.0            5.0            5.0
# mean       829808.4       550083.6       279724.0
# std    859313.83357  593417.874639  266255.481521
# min        209657.0       133055.0        76601.0
# 25%        326959.0       211124.0       115834.0
# 50%        621388.0       389993.0       231395.0
# 75%        662916.0       427372.0       235543.0
# max       2328122.0      1588874.0       739247.0

# %% [markdown]
# ## Região: graduados em educação, saúde e bem-estar

# %%
df_saude_educacao = pd.DataFrame([
    {'Região': 'Norte', 'Total': 599785, 'Homens': 141169, 'Mulheres': 458616},
    {'Região': 'Nordeste', 'Total': 1822087, 'Homens': 363905, 'Mulheres': 1458181},
    {'Região': 'Sudeste', 'Total': 3652397, 'Homens': 768288, 'Mulheres': 2884108},
    {'Região': 'Sul', 'Total': 1256291, 'Homens': 248574, 'Mulheres': 1007718},
    {'Região': 'Centro-Oeste', 'Total': 749148, 'Homens': 156048, 'Mulheres': 593101}
])
df_saude_educacao

# %%
df_saude_educacao.describe()
# Out:
#                 Total         Homens       Mulheres
# count             5.0            5.0            5.0
# mean        1615941.6       335596.8      1280344.8
# std    1235202.458803  257699.406993  977950.631317
# min          599785.0       141169.0       458616.0
# 25%          749148.0       156048.0       593101.0
# 50%         1256291.0       248574.0      1007718.0
# 75%         1822087.0       363905.0      1458181.0
# max         3652397.0       768288.0      2884108.0
